# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **과제1**

# %%
url = 'https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC'
dfs =  pd.read_html(url)

# %%
dfs[1]
# Out:
#                 종류                                                 설명  \
# 0              str                      문자열: 이뮤터블 방식의 일련의 유니코드 코드포인트.
# 1        bytearray                          뮤터블(mutable) 방식의 일련의 바이트.
# 2            bytes                       이뮤터블(immutable) 방식의 일련의 바이트.
# 3             list             뮤터블(mutable) 방식의 리스트. 혼합 형태를 포함할 수 있다.
# 4            tuple               이뮤터블(immutable) 방식. 혼합 형태를 포함할 수 있다.
# 5   set, frozenset  순서가 정해지지 않은 집합. 중복 허용 안 함. frozenset은 이뮤터블(imm...
# 6             dict                    뮤터블(mutable) 방식의 연관 배열의 키와 값 쌍.
# 7              int                  이뮤터블(immutable) 방식의 정수로서 크기는 무제한.
# 8            float          이뮤터블(immutable) 방식의 부동소수점 수 (시스템 정의 정밀도).
# 9          complex                  이뮤터블(immutable) 방식의 복소수. (실수와 허수)
# 10            bool                           이뮤터블(immutable) 방식의 진리값.
#
#                                                  문법 예
# 0   'Wikipedia'"Wikipedia""""Spanningmultiplelines"""
# ...

# %% [markdown]
# **과제2**

# %%
movies = pd.read_csv("pandas_data/movie.csv")
movies.info() #1.1MB의 메모리가 필요
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
'''
정수, 실수 형변환
num_critic_for_reviews = float16
duration = float16
director_facebook_likes = float16
actor_3_facebook_likes = float16
actor_1_facebook_likes = float32
gross = float32
num_voted_users = int32
cast_total_facebook_likes = int32
facenumber_in_poster = float16
num_user_for_reviews = float16
budget = float32
title_year = float16
actor_2_facebook_likes = flaot32
imdb_score = float16
aspect_ratio = float16
movie_facebook_likes = int32
'''
movies.describe().T
# Out:
#                             count          mean           std      min  \
# num_critic_for_reviews     4867.0  1.379889e+02  1.202394e+02     1.00
# duration                   4901.0  1.070908e+02  2.528602e+01     7.00
# director_facebook_likes    4814.0  6.910145e+02  2.832954e+03     0.00
# actor_3_facebook_likes     4893.0  6.312763e+02  1.625875e+03     0.00
# actor_1_facebook_likes     4909.0  6.494488e+03  1.510699e+04     0.00
# gross                      4054.0  4.764451e+07  6.737255e+07   162.00
# num_voted_users            4916.0  8.264492e+04  1.383222e+05     5.00
# cast_total_facebook_likes  4916.0  9.579816e+03  1.816432e+04     0.00
# facenumber_in_poster       4903.0  1.377320e+00  2.023826e+00     0.00
# num_user_for_reviews       4895.0  2.676688e+02  3.729348e+02     1.00
# budget                     4432.0  3.654749e+07  1.002427e+08   218.00
# title_year                 4810.0  2.002448e+03  1.245398e+01  1916.00
# ...

# %%
movies2 = pd.read_csv('pandas_data/movie.csv',
                      dtype = {'num_critic_for_review':np.float16,
                                'duration':np.float16,
                                'director_facebook_likes':np.float16,
                                'actor_3_facebook_likes':np.float16,
                                'actor_1_facebook_likes':np.float32,
                                'gross':np.float32,
                                'num_voted_users':np.int32,
                                'cast_total_facebook_likes':np.int32,
                                'facenumber_in_poster':np.float16,
                                'num_user_for_reviews':np.float16,
                                'budget':np.float32,
                                'title_year':np.float16,
                                'actor_2_facebook_likes':np.float32,
                                'imdb_score':np.float16,
                                'aspect_ratio':np.float16,
                                'movie_facebook_likes':np.int32}
                     )

# %%
movies2.info() #710.6KB 기존보다 약 65%의 메모리만 사용한다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float16
#  4   director_facebook_likes    4814 non-null   float16
#  5   actor_3_facebook_likes     4893 non-null   float16
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float32
#  8   gross                      4054 non-null   float32
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int32
# ...

# %%
movies2.describe(include = 'O') # color의 unique값은 2개로 binary한 category로 볼 수 있다.
# Out:
#         color     director_name    actor_2_name genres    actor_1_name  \
# count    4897              4814            4903   4916            4909
# unique      2              2397            3030    914            2095
# top     Color  Steven Spielberg  Morgan Freeman  Drama  Robert De Niro
# freq     4693                26              18    233              48
#
#        movie_title  actor_3_name   plot_keywords  \
# count         4916          4893            4764
# unique        4916          3519            4756
# top         Avatar  Steve Coogan  based on novel
# freq             1             8               4
#
#                                           movie_imdb_link language country  \
# count                                                4916     4904    4911
# unique                                               4916       47      65
# top     http://www.imdb.com/title/tt0499549/?ref_=fn_t...  English     USA
# ...

# %%
movies3 = pd.read_csv('pandas_data/movie.csv',
                      dtype = {'color':'category',
                               'num_critic_for_review':np.float16,
                                'duration':np.float16,
                                'director_facebook_likes':np.float16,
                                'actor_3_facebook_likes':np.float16,
                                'actor_1_facebook_likes':np.float32,
                                'gross':np.float32,
                                'num_voted_users':np.int32,
                                'cast_total_facebook_likes':np.int32,
                                'facenumber_in_poster':np.float16,
                                'num_user_for_reviews':np.float16,
                                'budget':np.float32,
                                'title_year':np.float16,
                                'actor_2_facebook_likes':np.float32,
                                'imdb_score':np.float16,
                                'aspect_ratio':np.float16,
                                'movie_facebook_likes':np.int32}
                     )

# %%
movies3.info() #677.2KB 기존보다 약 60%의 메모리만 사용한다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   category
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float16
#  4   director_facebook_likes    4814 non-null   float16
#  5   actor_3_facebook_likes     4893 non-null   float16
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float32
#  8   gross                      4054 non-null   float32
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int32
# ...
